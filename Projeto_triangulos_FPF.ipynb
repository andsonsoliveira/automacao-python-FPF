# %%
import pytest
from selenium import webdriver

    # inicializando o webdriver
driver = webdriver.Chrome()
    # navegando para a página do triângulo
driver.get("http://www.vanilton.net/triangulo/")

    # localizando os campos de entrada para os lados do triângulo
    
espaço1 = driver.find_element('name', 'V1')
espaço2 = driver.find_element('name', 'V2')
espaço3 = driver.find_element('name', 'V3')

    # localizando e clicando no botão de submit
identify_button = driver.find_element('xpath', '/html/body/form/input[4]')
    
    # Test case 1: Triângulo equilátero
espaço1.send_keys("3")
espaço2.send_keys("3")
espaço3.send_keys("3")
identify_button.click()
output = driver.find_element('xpath', '/html/body/div[4]').text
try:
    assert output == "Equilátero"
    print("Test case 1: PASSED")
except AssertionError:
    print("Test case 1: FAILED")
driver.quit()
import pytest
from selenium import webdriver

    # inicializando o webdriver
driver = webdriver.Chrome()
    # navegando para a página do triângulo
driver.get("http://www.vanilton.net/triangulo/")

    # localizando os campos de entrada para os lados do triângulo
    
espaço1 = driver.find_element('name', 'V1')
espaço2 = driver.find_element('name', 'V2')
espaço3 = driver.find_element('name', 'V3')

    # localizando e clicando no botão de submit
identify_button = driver.find_element('xpath', '/html/body/form/input[4]')
    
    # Test case 2: Triângulo isósceles
espaço1.send_keys("3")
espaço2.send_keys("3")
espaço3.send_keys("2")
identify_button.click()
output = driver.find_element('xpath', '/html/body/div[4]').text
try:
    assert output == "Isósceles"
    print("Test case 2: PASSED")
except AssertionError:
    print("Test case 2: FAILED")
driver.quit()
import pytest
from selenium import webdriver

    # inicializando o webdriver
driver = webdriver.Chrome()
    # navegando para a página do triângulo
driver.get("http://www.vanilton.net/triangulo/")

    # localizando os campos de entrada para os lados do triângulo
    
espaço1 = driver.find_element('name', 'V1')
espaço2 = driver.find_element('name', 'V2')
espaço3 = driver.find_element('name', 'V3')

    # localizando e clicando no botão de submit
identify_button = driver.find_element('xpath', '/html/body/form/input[4]')
    
    # Test case 3: Triângulo Escaleno
espaço1.send_keys("1")
espaço2.send_keys("2")
espaço3.send_keys("3")
identify_button.click()
output = driver.find_element('xpath', '/html/body/div[4]').text
try:
    assert output == "Escaleno"
    print("Test case 3: PASSED")
except AssertionError:
    print("Test case 3: FAILED")
driver.quit()    
import pytest
from selenium import webdriver

    # inicializando o webdriver
driver = webdriver.Chrome()
    # navegando para a página do triângulo
driver.get("http://www.vanilton.net/triangulo/")

    # localizando os campos de entrada para os lados do triângulo
    
espaço1 = driver.find_element('name', 'V1')
espaço2 = driver.find_element('name', 'V2')
espaço3 = driver.find_element('name', 'V3')

    # localizando e clicando no botão de submit
identify_button = driver.find_element('xpath', '/html/body/form/input[4]')
    
    # Test case 4: Teste com digitos que não formam um triangulo
espaço1.send_keys("1")
espaço2.send_keys("2")
espaço3.send_keys("3")
identify_button.click()
output = driver.find_element('xpath', '/html/body/div[4]').text
try:
    assert output == "impossivel formar um triangulo"
    print("Test case 4: PASSED")
except AssertionError:
    print("Test case 4: FAILED")
    
driver.quit()
# Out:
# Test case 1: PASSED
# Test case 2: PASSED
# Test case 3: PASSED
# Test case 4: FAILED
